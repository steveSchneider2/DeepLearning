# %% [markdown]
# # -*- coding: utf-8 -*-
# """Tensorboard in 5 mins.ipynb
# Automatically generated by Colaboratory.
# Original file is located at     https://colab.research.google.com/github/manifoldailearning/Youtube/blob/master/Tensorboard_in_5_mins.ipynb
# [Check out Video for explanation](https://www.youtube.com/watch?v=Uzkhn5ENJzQ&feature=youtu.be)
# """

# %%
import tensorflow as tf
import datetime

mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.summary()

model.compile(optimizer='adagrad',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


path = "logs\\fit\\" + datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=path, histogram_freq=1)

model.fit(x=x_train, 
          y=y_train, 
          epochs=20, 
          validation_data=(x_test, y_test), 
          callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.5207 - accuracy: 0.5847 - val_loss: 0.6091 - val_accuracy: 0.8669
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5985 - accuracy: 0.8558 - val_loss: 0.4501 - val_accuracy: 0.8914
# Epoch 3/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4747 - accuracy: 0.8764 - val_loss: 0.3908 - val_accuracy: 0.9015
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4207 - accuracy: 0.8883 - val_loss: 0.3584 - val_accuracy: 0.9080
# Epoch 5/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3902 - accuracy: 0.8956 - val_loss: 0.3363 - val_accuracy: 0.9118
# Epoch 6/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3664 - accuracy: 0.9009 - val_loss: 0.3201 - val_accuracy: 0.9150
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3504 - accuracy: 0.9030 - val_loss: 0.3075 - val_accuracy: 0.9192
# Epoch 8/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3386 - accuracy: 0.9050 - val_loss: 0.2967 - val_accuracy: 0.9199
# Epoch 9/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3241 - accuracy: 0.9103 - val_loss: 0.2878 - val_accuracy: 0.9225
# Epoch 10/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3179 - accuracy: 0.9114 - val_loss: 0.2803 - val_accuracy: 0.9247
# Epoch 11/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3109 - accuracy: 0.9127 - val_loss: 0.2735 - val_accuracy: 0.9257
# Epoch 12/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3044 - accuracy: 0.9140 - val_loss: 0.2675 - val_accuracy: 0.9271
# Epoch 13/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2907 - accuracy: 0.9198 - val_loss: 0.2618 - val_accuracy: 0.9282
# Epoch 14/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2823 - accuracy: 0.9220 - val_loss: 0.2566 - val_accuracy: 0.9295
# Epoch 15/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2750 - accuracy: 0.9232 - val_loss: 0.2516 - val_accuracy: 0.9303
# Epoch 16/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2745 - accuracy: 0.9238 - val_loss: 0.2475 - val_accuracy: 0.9309
# Epoch 17/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2687 - accuracy: 0.9256 - val_loss: 0.2435 - val_accuracy: 0.9315
# Epoch 18/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2681 - accuracy: 0.9253 - val_loss: 0.2396 - val_accuracy: 0.9327
# Epoch 19/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2594 - accuracy: 0.9274 - val_loss: 0.2362 - val_accuracy: 0.9343
# Epoch 20/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2583 - accuracy: 0.9281 - val_loss: 0.2326 - val_accuracy: 0.9349

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs\\fit\\20210604_175004
# Out:
#       <iframe id="tensorboard-frame-e9ca926efe7f5b7a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e9ca926efe7f5b7a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
